# %% [markdown]
# This code is used to generate EURO2021 & EURO2025 boundary for zonal statistics.
#
# - EURO2021 (2243): NUTS 2021 (2010) + ITL 2021 (232) + 1
# - EURO2025 (2039): NUTS 2024 (1798) + ITL 2025 (240) + 1
#
# Data wrangling steps:
# 1. read in NUTS (3035, Drop: 'NAME_LATN', 'MOUNT_TYPE', 'MOUNT_TYPE', 'URBN_TYPE', 'COAST_TYPE')
# and ITL (27700, Drop: 'BNG_E', 'BNG_N') seperatly
# 2. Change both CRS to Equal earth (EPSG:8857, ref: https://epsg.io/8857)
# 3. Get the boundary of UK ITL for 2021 and 2025, and make sure the name is not the same with NUTS （renamed to UK0 to ITL）
# > note: the EURO has 2 complete (level0 to level 3) data of UK, from NUTS and UK
# 4. Export as 8857 for geojson, and 4326 for shp for GEE

# %%
import re
import os
import gc
import json
import fiona
import shutil
import rasterio
import numpy as np
import pandas as pd
from tqdm import tqdm
import geopandas as gpd
from pathlib import Path
from osgeo import gdal, osr
import dask_geopandas as dgpd
from shapely.geometry import shape
from rasterstats import zonal_stats
import geopandas as gpd
import fiona

BASE_DIR = Path('/Users/wenlanzhang/PycharmProjects/Mapineq/src/data-wrangling/')
DATA_DIR = Path('/Users/wenlanzhang/Downloads/PhD_UCL/Data/Oxford')

# Target CRS: Equal Earth
target_crs = "EPSG:8857"

# %% [markdown]
# # Load ITL and NUTS

# %% [markdown]
# ## Load ITL

# %%
# Paths to your shapefiles — replace these with actual file paths
itl_2021_path = DATA_DIR/"ITL/itl_2021_BGC.shp"
itl_2025_path = DATA_DIR/"ITL/itl_2025_BGC.shp"

# Read the shapefiles
itl_2021 = gpd.read_file(itl_2021_path)
itl_2025 = gpd.read_file(itl_2025_path)

itl_2021 = itl_2021.drop(columns=['BNG_E', 'BNG_N', 'LONG', 'LAT', 'GlobalID'])
itl_2025 = itl_2025.drop(columns=['BNG_E', 'BNG_N', 'LONG', 'LAT', 'GlobalID'])

itl_2021['CNTR_CODE'] = 'UK'
itl_2025['CNTR_CODE'] = 'UK'

itl_2021
# itl_2025.sort_values(by="ITL_CODE")
# Out:
#     ITL_CODE                             ITL_NAME  ITL_LEVEL  \
# 0        TLC                 North East (England)          1
# 1        TLD                 North West (England)          1
# 2        TLE             Yorkshire and The Humber          1
# 3        TLF              East Midlands (England)          1
# 4        TLG              West Midlands (England)          1
# ..       ...                                  ...        ...
# 227    TLN0E              Lisburn and Castlereagh          3
# 228    TLN0F                  Mid and East Antrim          3
# 229    TLN0G                  Fermanagh and Omagh          3
# 230    TLK24  Bournemouth, Christchurch and Poole          3
# 231    TLK25                               Dorset          3
#
#                                               geometry CNTR_CODE
# 0    MULTIPOLYGON (((402039.597 506235.701, 401929....        UK
# 1    MULTIPOLYGON (((364516.901 338994.103, 364347....        UK
# 2    MULTIPOLYGON (((450524.201 378564.296, 450416....        UK
# 3    MULTIPOLYGON (((455182.298 231283.095, 455000....        UK
# 4    POLYGON ((403387.797 368314.9, 403515.999 3682...        UK
# ..                                                 ...       ...
# 227  POLYGON ((138843.75 530937.408, 138876.343 530...        UK
# 228  POLYGON ((112237.347 552083.778, 112276.828 55...        UK
# 229  POLYGON ((80027.441 554144.198, 80556.966 5533...        UK
# 230  MULTIPOLYGON (((403839.945 87004.556, 403705.2...        UK
# 231  MULTIPOLYGON (((367721.4 68247.6, 367660.3 682...        UK
#
# [232 rows x 5 columns]

# %%
# Reproject ITL 
itl_2021 = itl_2021.to_crs(target_crs)
itl_2025 = itl_2025.to_crs(target_crs)

# %%
# --- Check CRS ---
print("ITL 2021 CRS:", itl_2021.crs)
print("ITL 2025 CRS:", itl_2025.crs)

print("CRS match:", itl_2021.crs == itl_2025.crs)
# Out:
# ITL 2021 CRS: EPSG:8857
# ITL 2025 CRS: EPSG:8857
# CRS match: True

# %%
# # ------------- Check the boundary ------------- 
# import matplotlib.pyplot as plt
# from shapely.geometry import box

# # Optional: reproject to match if needed
# if itl_2021.crs != itl_2025.crs:
#     itl_2025 = itl_2025.to_crs(itl_2021.crs)

# # Plot both shapefiles
# fig, ax = plt.subplots(figsize=(10, 10))
# itl_2021.plot(ax=ax, edgecolor='blue', facecolor='none', label='ITL 2021')
# itl_2025.plot(ax=ax, edgecolor='red', facecolor='none', linestyle='--', label='ITL 2025')
# # plt.legend()
# plt.title("ITL 2021 (blue) vs ITL 2025 (red dashed)")
# plt.show()

# %% [markdown]
# ## Load NUTS

# %%
# Read the shapefiles
NUTS_2021 = gpd.read_file(DATA_DIR/"NUTS/NUTS_RG_01M_2021_3035.geojson")
NUTS_2024 = gpd.read_file(DATA_DIR/"NUTS/NUTS_RG_01M_2024_3035.geojson")

NUTS_2021 = NUTS_2021.drop(columns=['NAME_LATN', 'MOUNT_TYPE', 'MOUNT_TYPE', 'URBN_TYPE', 'COAST_TYPE'])
NUTS_2024 = NUTS_2024.drop(columns=['NAME_LATN', 'MOUNT_TYPE', 'MOUNT_TYPE', 'URBN_TYPE', 'COAST_TYPE'])

NUTS_2021
# Out:
#      NUTS_ID  LEVL_CODE CNTR_CODE               NUTS_NAME  \
# 0         AL          0        AL               Shqipëria
# 1         CZ          0        CZ                   Česko
# 2         DE          0        DE             Deutschland
# 3         DK          0        DK                 Danmark
# 4         CY          0        CY                  Κύπρος
# ...      ...        ...       ...                     ...
# 2005   NO0B1          3        NO               Jan Mayen
# 2006   EE009          3        EE              Kesk-Eesti
# 2007     NO0          1        NO                   Norge
# 2008    NO0B          2        NO  Jan Mayen and Svalbard
# 2009   NO0B2          3        NO                Svalbard
#
#                                                geometry
# 0     MULTIPOLYGON (((5121233.536 2221719.441, 51208...
# 1     POLYGON ((4624843.654 3112209.741, 4625546.618...
# 2     MULTIPOLYGON (((4355225.365 2715902.993, 43541...
# 3     MULTIPOLYGON (((4650502.736 3591342.844, 46503...
# 4     MULTIPOLYGON (((6527040.718 1762367.593, 65267...
# ...                                                 ...
# 2005  POLYGON ((3623747.621 5400386.841, 3624031.138...
# 2006  MULTIPOLYGON (((5216227.688 4159212.769, 52172...
# 2007  MULTIPOLYGON (((4961367.759 5413266.131, 49622...
# 2008  MULTIPOLYGON (((4744650.828 6379141.635, 47446...
# 2009  MULTIPOLYGON (((4760536.161 6404487.632, 47607...
#
# [2010 rows x 5 columns]

# %%
# Reproject NUTS 
NUTS_2021 = NUTS_2021.to_crs(target_crs)
NUTS_2024 = NUTS_2024.to_crs(target_crs)

# --- Check CRS ---
print("NUTS 2021 CRS:", NUTS_2021.crs)
print("NUTS 2024 CRS:", NUTS_2024.crs)

print("CRS match:", NUTS_2021.crs == NUTS_2024.crs)
# Out:
# NUTS 2021 CRS: EPSG:8857
# NUTS 2024 CRS: EPSG:8857
# CRS match: True

# %%
# Check UK in NUTS

NUTS_2021[(NUTS_2021['CNTR_CODE'] == 'UK') & (NUTS_2021['LEVL_CODE'] == 0)]
# Out:
#    NUTS_ID  LEVL_CODE CNTR_CODE       NUTS_NAME  \
# 60      UK          0        UK  United Kingdom
#
#                                              geometry
# 60  MULTIPOLYGON (((-249800.512 6805458.936, -2495...

# %% [markdown]
# # Get boundary for UK (level0)

# %%
itl_2021 = itl_2021.to_crs(target_crs)
itl_2025 = itl_2025.to_crs(target_crs)
itl_2021.crs
# Out:
# <Projected CRS: EPSG:8857>
# Name: WGS 84 / Equal Earth Greenwich
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Coordinate Operation:
# - name: Equal Earth Greenwich
# - method: Equal Earth
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# import geopandas as gpd
from shapely.ops import unary_union

# Select ITL_LEVEL==1
level_1_2021 = itl_2021[itl_2021['ITL_LEVEL'] == 1]

# Merge geometries
merged_geometry = unary_union(level_1_2021.geometry)

# Create new row as a GeoDataFrame
new_row = gpd.GeoDataFrame([{
    'ITL_CODE': 'ITL',
    'ITL_NAME': 'United Kingdom',
    'ITL_LEVEL': 0,
    'CNTR_CODE': 'UK',
    'geometry': merged_geometry
}], crs=level_1_2021.crs)  # Keep same CRS

# Append to original GeoDataFrame
itl_2021_0 = pd.concat([itl_2021, new_row], ignore_index=True)

itl_2021_0
# Out:
#     ITL_CODE                             ITL_NAME  ITL_LEVEL  \
# 0        TLC                 North East (England)          1
# 1        TLD                 North West (England)          1
# 2        TLE             Yorkshire and The Humber          1
# 3        TLF              East Midlands (England)          1
# 4        TLG              West Midlands (England)          1
# ..       ...                                  ...        ...
# 228    TLN0F                  Mid and East Antrim          3
# 229    TLN0G                  Fermanagh and Omagh          3
# 230    TLK24  Bournemouth, Christchurch and Poole          3
# 231    TLK25                               Dorset          3
# 232      ITL                       United Kingdom          0
#
#                                               geometry CNTR_CODE
# 0    MULTIPOLYGON (((-150023.597 6421565.781, -1501...        UK
# 1    MULTIPOLYGON (((-195202.511 6277323.483, -1953...        UK
# 2    MULTIPOLYGON (((-95651.593 6311598.73, -95775....        UK
# 3    MULTIPOLYGON (((-93223.092 6182667.126, -93428...        UK
# 4    POLYGON ((-150190.618 6302937.743, -150043.155...        UK
# ..                                                 ...       ...
# 228  POLYGON ((-491777.644 6452716.713, -491783.497...        UK
# 229  POLYGON ((-529839.115 6452618.654, -529180.739...        UK
# 230  MULTIPOLYGON (((-153158.042 6054365.176, -1533...        UK
# 231  MULTIPOLYGON (((-193514.723 6037399.646, -1935...        UK
# 232  MULTIPOLYGON (((-570192.843 6638671.643, -5702...        UK
#
# [233 rows x 5 columns]

# %%
# Select ITL_LEVEL==1
level_1_2025 = itl_2025[itl_2025['ITL_LEVEL'] == 1]
merged_geometry_2025 = unary_union(level_1_2025.geometry)

new_row_2025 = gpd.GeoDataFrame([{
    'ITL_CODE': 'ITL',
    'ITL_NAME': 'United Kingdom',
    'ITL_LEVEL': 0,
    'CNTR_CODE': 'UK',
    'geometry': merged_geometry_2025
}], crs=itl_2025.crs)

itl_2025_0 = pd.concat([itl_2025, new_row_2025], ignore_index=True)
itl_2025_0
# Out:
#     ITL_CODE                  ITL_NAME  ITL_LEVEL  \
# 0        TLC      North East (England)          1
# 1        TLD      North West (England)          1
# 2        TLE  Yorkshire and The Humber          1
# 3        TLF   East Midlands (England)          1
# 4        TLG   West Midlands (England)          1
# ..       ...                       ...        ...
# 236    TLN0D   Antrim and Newtownabbey          3
# 237    TLN0E   Lisburn and Castlereagh          3
# 238    TLN0F       Mid and East Antrim          3
# 239    TLN0G       Fermanagh and Omagh          3
# 240      ITL            United Kingdom          0
#
#                                               geometry CNTR_CODE
# 0    MULTIPOLYGON (((-92979.343 6438074.46, -93140....        UK
# 1    MULTIPOLYGON (((-237283.047 6307176.377, -2372...        UK
# 2    MULTIPOLYGON (((-42588.825 6348997.161, -41892...        UK
# 3    MULTIPOLYGON (((20764.971 6264583.126, 20664.3...        UK
# 4    POLYGON ((-103473.72 6201427.643, -103567.255 ...        UK
# ..                                                 ...       ...
# 236  POLYGON ((-446001.709 6444035.837, -446350.658...        UK
# 237  POLYGON ((-459814.875 6436192.627, -459774.891...        UK
# 238  POLYGON ((-446001.709 6444035.837, -446006.781...        UK
# 239  POLYGON ((-527029.551 6452031.269, -526758.281...        UK
# 240  MULTIPOLYGON (((-570184.256 6638699.647, -5701...        UK
#
# [241 rows x 5 columns]

# %%
itl_2025_0[itl_2025_0['ITL_CODE'] == 'ITL']
# Out:
#     ITL_CODE        ITL_NAME  ITL_LEVEL  \
# 240      ITL  United Kingdom          0
#
#                                               geometry CNTR_CODE
# 240  MULTIPOLYGON (((-570184.256 6638699.647, -5701...        UK

# %% [markdown]
# # Combine

# %% [markdown]
# ## 2021

# %%
# NUTS_2021
itl_2025_0
# Out:
#     ITL_CODE                  ITL_NAME  ITL_LEVEL  \
# 0        TLC      North East (England)          1
# 1        TLD      North West (England)          1
# 2        TLE  Yorkshire and The Humber          1
# 3        TLF   East Midlands (England)          1
# 4        TLG   West Midlands (England)          1
# ..       ...                       ...        ...
# 236    TLN0D   Antrim and Newtownabbey          3
# 237    TLN0E   Lisburn and Castlereagh          3
# 238    TLN0F       Mid and East Antrim          3
# 239    TLN0G       Fermanagh and Omagh          3
# 240      ITL            United Kingdom          0
#
#                                               geometry CNTR_CODE
# 0    MULTIPOLYGON (((-92979.343 6438074.46, -93140....        UK
# 1    MULTIPOLYGON (((-237283.047 6307176.377, -2372...        UK
# 2    MULTIPOLYGON (((-42588.825 6348997.161, -41892...        UK
# 3    MULTIPOLYGON (((20764.971 6264583.126, 20664.3...        UK
# 4    POLYGON ((-103473.72 6201427.643, -103567.255 ...        UK
# ..                                                 ...       ...
# 236  POLYGON ((-446001.709 6444035.837, -446350.658...        UK
# 237  POLYGON ((-459814.875 6436192.627, -459774.891...        UK
# 238  POLYGON ((-446001.709 6444035.837, -446006.781...        UK
# 239  POLYGON ((-527029.551 6452031.269, -526758.281...        UK
# 240  MULTIPOLYGON (((-570184.256 6638699.647, -5701...        UK
#
# [241 rows x 5 columns]

# %%
# --- For ITL dataset ---
itl_2021_0 = itl_2021_0.rename(columns={
    "ITL_CODE": "EURO_CODE",
    "ITL_NAME": "EURO_NAME",
    "ITL_LEVEL": "EURO_LEVEL"
})
# itl_df = itl_df[["EURO_CODE", "EURO_NAME", "geometry"]]  # select needed columns

# --- For NUTS dataset ---
NUTS_2021 = NUTS_2021.rename(columns={
    "NUTS_ID": "EURO_CODE",
    "NUTS_NAME": "EURO_NAME",
    "LEVL_CODE": "EURO_LEVEL"
})
# nuts_df = nuts_df[["EURO_CODE", "EURO_NAME", "geometry"]]

# --- Concatenate into a single GeoDataFrame ---
combined_2021 = pd.concat([itl_2021_0, NUTS_2021], ignore_index=True)

# --- Convert back to GeoDataFrame (keep CRS from one of the datasets) ---
combined_2021 = gpd.GeoDataFrame(combined_2021, geometry="geometry", crs=itl_2021_0.crs)

combined_2021
# Out:
#      EURO_CODE                 EURO_NAME  EURO_LEVEL  \
# 0          TLC      North East (England)           1
# 1          TLD      North West (England)           1
# 2          TLE  Yorkshire and The Humber           1
# 3          TLF   East Midlands (England)           1
# 4          TLG   West Midlands (England)           1
# ...        ...                       ...         ...
# 2238     NO0B1                 Jan Mayen           3
# 2239     EE009                Kesk-Eesti           3
# 2240       NO0                     Norge           1
# 2241      NO0B    Jan Mayen and Svalbard           2
# 2242     NO0B2                  Svalbard           3
#
#                                                geometry CNTR_CODE
# 0     MULTIPOLYGON (((-150023.597 6421565.781, -1501...        UK
# 1     MULTIPOLYGON (((-195202.511 6277323.483, -1953...        UK
# 2     MULTIPOLYGON (((-95651.593 6311598.73, -95775....        UK
# 3     MULTIPOLYGON (((-93223.092 6182667.126, -93428...        UK
# 4     POLYGON ((-150190.618 6302937.743, -150043.155...        UK
# ...                                                 ...       ...
# 2238  POLYGON ((-585620.093 7743197.571, -585306.164...        NO
# 2239  MULTIPOLYGON (((1884405.458 6891313.753, 18856...        EE
# 2240  MULTIPOLYGON (((1781507.126 7758918.947, 17830...        NO
# 2241  MULTIPOLYGON (((1881228.3 8208517.602, 1882472...        NO
# 2242  MULTIPOLYGON (((1953272.702 8214619.941, 19537...        NO
#
# [2243 rows x 5 columns]

# %%
combined_2021[combined_2021['EURO_LEVEL'] == 0]
# Out:
#     EURO_CODE                EURO_NAME  EURO_LEVEL  \
# 232       ITL           United Kingdom           0
# 233        AL                Shqipëria           0
# 234        CZ                    Česko           0
# 235        DE              Deutschland           0
# 236        DK                  Danmark           0
# 237        CY                   Κύπρος           0
# 238        BE          Belgique/België           0
# 239        BG                 България           0
# 240        CH  Schweiz/Suisse/Svizzera           0
# 241        AT               Österreich           0
# 242        EE                    Eesti           0
# 243        EL                   Ελλάδα           0
# 244        ES                   España           0
# 245        FI            Suomi/Finland           0
# 246        FR                   France           0
# 247        HR                 Hrvatska           0
# 248        HU             Magyarország           0
# 249        IE             Éire/Ireland           0
# 250        IS                   Ísland           0
# 251        IT                   Italia           0
# 254        LV                  Latvija           0
# 257        ME                Црна Гора           0
# 258        MT                    Malta           0
# 259        NO                    Norge           0
# 262        MK       Северна Македонија           0
# 264        LT                  Lietuva           0
# 265        LU               Luxembourg           0
# 267        NL                Nederland           0
# 269        SI                Slovenija           0
# 270        LI            Liechtenstein           0
# 271        SE                  Sverige           0
# 272        PL                   Polska           0
# 289        SK                Slovensko           0
# 291        RS            Srbija/Сpбија           0
# 292        TR                  Türkiye           0
# 293        UK           United Kingdom           0
# 307        RO                  România           0
# 328        PT                 Portugal           0
#
#                                               geometry CNTR_CODE
# 232  MULTIPOLYGON (((-570192.843 6638671.643, -5702...        UK
# 233  MULTIPOLYGON (((1650425.741 5211648.283, 16499...        AL
# 234  POLYGON ((1124307.66 6090003.519, 1125097.315 ...        CZ
# 235  MULTIPOLYGON (((843062.368 5735775.013, 842061...        DE
# 236  MULTIPOLYGON (((1147917.715 6503373.5, 1147753...        DK
# 237  MULTIPOLYGON (((3015419.669 4434050.531, 30150...        CY
# 238  MULTIPOLYGON (((378499.891 6131545.983, 378245...        BE
# 239  POLYGON ((1873829.714 5382911.359, 1875271.231...        BG
# 240  POLYGON ((689976.87 5761662.831, 690334.538 57...        CH
# 241  MULTIPOLYGON (((842061.301 5732543.425, 843062...        AT
# 242  MULTIPOLYGON (((1863627.578 6894610.494, 18638...        EE
# 243  MULTIPOLYGON (((2576554.826 4480425.703, 25763...        EL
# 244  MULTIPOLYGON (((347720.775 4927912.121, 348578...        ES
# 245  MULTIPOLYGON (((1817595.905 7693383.051, 18193...        FI
# 246  MULTIPOLYGON (((5146240.52 -2651750.07, 514696...        FR
# 247  MULTIPOLYGON (((1330244.636 5630504.295, 13302...        HR
# 248  MULTIPOLYGON (((1718860.519 5839790.7, 1719442...        HU
# 249  MULTIPOLYGON (((-551810.295 6507873.51, -55148...        IE
# 250  MULTIPOLYGON (((-1081460.098 7446495.372, -108...        IS
# 251  MULTIPOLYGON (((989398.965 5686553.984, 990767...        IT
# 254  MULTIPOLYGON (((1855885.971 6755900.497, 18565...        LV
# 257  MULTIPOLYGON (((1541113.438 5203123.125, 15417...        ME
# 258  MULTIPOLYGON (((1250037.959 4467374.601, 12506...        MT
# 259  MULTIPOLYGON (((1781507.126 7758918.947, 17830...        NO
# 262  POLYGON ((1866145.803 5182317.181, 1865732.488...        MK
# 264  MULTIPOLYGON (((1860702.177 6608117.192, 18611...        LT
# 265  POLYGON ((477623.187 6001738.875, 479120.04 60...        LU
# 267  MULTIPOLYGON (((518760.781 6327400.7, 522102.5...        NL
# 269  MULTIPOLYGON (((1316520.232 5664997.445, 13180...        SI
# 270  POLYGON ((773709.921 5695638.339, 774232.85 56...        LI
# 271  MULTIPOLYGON (((1646380.606 7378368.327, 16460...        SE
# 272  MULTIPOLYGON (((1390904.571 6457780.558, 13916...        PL
# 289  MULTIPOLYGON (((1544757.639 5946807.569, 15454...        SK
# 291  MULTIPOLYGON (((1601824.599 5592896.531, 16037...        RS
# 292  MULTIPOLYGON (((2929749.108 5152974.743, 29326...        TR
# 293  MULTIPOLYGON (((-249800.512 6805458.936, -2495...        UK
# 307  MULTIPOLYGON (((2142306.626 5807800.521, 21433...        RO
# 328  MULTIPOLYGON (((-686475.427 5157094.293, -6867...        PT

# %% [markdown]
# ## 2025

# %%
# --- For ITL dataset ---
itl_2025_0 = itl_2025_0.rename(columns={
    "ITL_CODE": "EURO_CODE",
    "ITL_NAME": "EURO_NAME",
    "ITL_LEVEL": "EURO_LEVEL"
})

# --- For NUTS dataset ---
NUTS_2024 = NUTS_2024.rename(columns={
    "NUTS_ID": "EURO_CODE",
    "NUTS_NAME": "EURO_NAME",
    "LEVL_CODE": "EURO_LEVEL"
})

# --- Concatenate into a single GeoDataFrame ---
combined_2025 = pd.concat([itl_2025_0, NUTS_2024], ignore_index=True)

# --- Convert back to GeoDataFrame (keep CRS from one of the datasets) ---
combined_2025 = gpd.GeoDataFrame(combined_2025, geometry="geometry", crs=itl_2021_0.crs)

combined_2025
# Out:
#      EURO_CODE                 EURO_NAME  EURO_LEVEL  \
# 0          TLC      North East (England)           1
# 1          TLD      North West (England)           1
# 2          TLE  Yorkshire and The Humber           1
# 3          TLF   East Midlands (England)           1
# 4          TLG   West Midlands (England)           1
# ...        ...                       ...         ...
# 2034        RO                   România           0
# 2035        NO                     Norge           0
# 2036        PL                    Polska           0
# 2037        PT                  Portugal           0
# 2038        XK                   Kosovo*           0
#
#                                                geometry CNTR_CODE
# 0     MULTIPOLYGON (((-92979.343 6438074.46, -93140....        UK
# 1     MULTIPOLYGON (((-237283.047 6307176.377, -2372...        UK
# 2     MULTIPOLYGON (((-42588.825 6348997.161, -41892...        UK
# 3     MULTIPOLYGON (((20764.971 6264583.126, 20664.3...        UK
# 4     POLYGON ((-103473.72 6201427.643, -103567.255 ...        UK
# ...                                                 ...       ...
# 2034  MULTIPOLYGON (((2142328.862 5807825.923, 21432...        RO
# 2035  MULTIPOLYGON (((1783587.536 7757929.018, 17831...        NO
# 2036  MULTIPOLYGON (((1388381.264 6457828.345, 13910...        PL
# 2037  MULTIPOLYGON (((-686422.937 5157351.023, -6867...        PT
# 2038  POLYGON ((1734787.619 5278572.755, 1736347.401...        XK
#
# [2039 rows x 5 columns]

# %%
combined_2025[combined_2025['EURO_LEVEL'] ==0 ]
# Out:
#      EURO_CODE                EURO_NAME  EURO_LEVEL  \
# 240        ITL           United Kingdom           0
# 1995        EL                  Ελλάδα            0
# 1996        ES                   España           0
# 1997        FI            Suomi/Finland           0
# 1998        FR                   France           0
# 1999        HR                 Hrvatska           0
# 2000        EE                    Eesti           0
# 2001        DE              Deutschland           0
# 2002        DK                  Danmark           0
# 2003        BA      Bosna I Hercegovina           0
# 2004        AT               Österreich           0
# 2006        BG                България            0
# 2008        CH  Schweiz/Suisse/Svizzera           0
# 2010        CY                  Κύπρος            0
# 2011        BE          Belgique/België           0
# 2014        CZ                    Česko           0
# 2015        AL                Shqipëria           0
# 2016        LU               Luxembourg           0
# 2017        LV                  Latvija           0
# 2018        ME               Црна Гора            0
# 2019        IE             Éire/Ireland           0
# 2020        IS                   Ísland           0
# 2021        IT                   Italia           0
# 2022        MK       Северна Македонија           0
# 2023        MT                    Malta           0
# 2024        LI            Liechtenstein           0
# 2025        NL                Nederland           0
# 2026        LT                  Lietuva           0
# 2027        HU             Magyarország           0
# 2028        RS            Srbija/Сpбија           0
# 2029        SE                  Sverige           0
# 2030        SI                Slovenija           0
# 2031        TR                  Türkiye           0
# 2032        UA                  Україна           0
# 2033        SK                Slovensko           0
# 2034        RO                  România           0
# 2035        NO                    Norge           0
# 2036        PL                   Polska           0
# 2037        PT                 Portugal           0
# 2038        XK                  Kosovo*           0
#
#                                                geometry CNTR_CODE
# 240   MULTIPOLYGON (((-570184.256 6638699.647, -5701...        UK
# 1995  MULTIPOLYGON (((2576551.636 4480196.117, 25764...        EL
# 1996  MULTIPOLYGON (((347746.578 4927919.43, 348590....        ES
# 1997  MULTIPOLYGON (((1811426.216 7692927.655, 18174...        FI
# 1998  MULTIPOLYGON (((5145544.442 -2652108.197, 5146...        FR
# 1999  MULTIPOLYGON (((1330343.362 5630462.009, 13304...        HR
# 2000  MULTIPOLYGON (((1864339.98 6894400.552, 186456...        EE
# 2001  MULTIPOLYGON (((843062.356 5735775.016, 842719...        DE
# 2002  MULTIPOLYGON (((1147654.269 6503666.403, 11480...        DK
# 2003  MULTIPOLYGON (((1390432.116 5494167.055, 13901...        BA
# 2004  MULTIPOLYGON (((842719.406 5734663.529, 843062...        AT
# 2006  MULTIPOLYGON (((1873829.7 5382911.35, 1875324....        BG
# 2008  POLYGON ((690120.492 5761441.393, 690361.86 57...        CH
# 2010  MULTIPOLYGON (((3015229.505 4433530.599, 30148...        CY
# 2011  MULTIPOLYGON (((377119.9 6130438.677, 377356.0...        BE
# 2014  MULTIPOLYGON (((1124306.146 6090010.388, 11250...        CZ
# 2015  MULTIPOLYGON (((1650110.092 5211169.213, 16499...        AL
# 2016  POLYGON ((477625.093 6001730.916, 479056.494 6...        LU
# 2017  MULTIPOLYGON (((1856355.684 6755401.219, 18562...        LV
# 2018  MULTIPOLYGON (((1581605.221 5306523.31, 158197...        ME
# 2019  MULTIPOLYGON (((-540935.849 6502300.047, -5405...        IE
# 2020  MULTIPOLYGON (((-1080141.274 7445308.832, -107...        IS
# 2021  MULTIPOLYGON (((986196.26 5687494.769, 989450....        IT
# 2022  POLYGON ((1866135.477 5182335.189, 1865908.592...        MK
# 2023  MULTIPOLYGON (((1248697.017 4464187.565, 12490...        MT
# 2024  POLYGON ((773721.741 5695942.591, 773572.86 56...        LI
# 2025  MULTIPOLYGON (((518586.705 6327366.873, 521865...        NL
# 2026  MULTIPOLYGON (((1862620.522 6605313.042, 18634...        LT
# 2027  POLYGON ((1717633.719 5840444.439, 1719442.141...        HU
# 2028  MULTIPOLYGON (((1603037.234 5592287.85, 160375...        RS
# 2029  MULTIPOLYGON (((1645993.152 7378698.199, 16463...        SE
# 2030  POLYGON ((1316520.223 5664997.436, 1318405.61 ...        SI
# 2031  MULTIPOLYGON (((2932857.117 5152520.478, 29352...        TR
# 2032  MULTIPOLYGON (((2573991.459 6222002.531, 25746...        UA
# 2033  MULTIPOLYGON (((1544757.628 5946807.555, 15453...        SK
# 2034  MULTIPOLYGON (((2142328.862 5807825.923, 21432...        RO
# 2035  MULTIPOLYGON (((1783587.536 7757929.018, 17831...        NO
# 2036  MULTIPOLYGON (((1388381.264 6457828.345, 13910...        PL
# 2037  MULTIPOLYGON (((-686422.937 5157351.023, -6867...        PT
# 2038  POLYGON ((1734787.619 5278572.755, 1736347.401...        XK

# %% [markdown]
# # Export

# %%
combined_2025[(combined_2025['CNTR_CODE'] == 'UK' ) & (combined_2025['EURO_LEVEL'] == 0 )]
# Out:
#     EURO_CODE       EURO_NAME  EURO_LEVEL  \
# 240       ITL  United Kingdom           0
#
#                                               geometry CNTR_CODE
# 240  MULTIPOLYGON (((-570184.256 6638699.647, -5701...        UK

# %%
combined_2021_4326[(combined_2021_4326['CNTR_CODE']=='UK') & (combined_2021_4326['EURO_LEVEL']==0)]
# Out:
#     EURO_CODE       EURO_NAME  EURO_LEVEL  \
# 232       ITL  United Kingdom           0
# 293        UK  United Kingdom           0
#
#                                               geometry CNTR_CODE
# 232  MULTIPOLYGON (((-7.6498 56.7838, -7.65075 56.7...        UK
# 293  MULTIPOLYGON (((-3.41143 58.6402, -3.40836 58....        UK

# %%
# Save as Shapefile
combined_2021_4326 = combined_2021.to_crs("EPSG:4326")
combined_2021_4326.to_file(DATA_DIR/"new/EURO_2021_BGC.shp")  

# Save as GeoJSON
combined_2021.to_file(DATA_DIR/"new/EURO_2021_BGC.geojson", driver="GeoJSON")

# %%
# Save as Shapefile
combined_2025_4326 = combined_2025.to_crs("EPSG:4326")
combined_2025_4326.to_file(DATA_DIR/"new/EURO_2025_BGC.shp")

# Save as GeoJSON
combined_2025.to_file(DATA_DIR/"new/EURO_2025_BGC.geojson", driver="GeoJSON")

# %%
combined_2025_4326
# Out:
#      EURO_CODE                 EURO_NAME  EURO_LEVEL  \
# 0          TLC      North East (England)           1
# 1          TLD      North West (England)           1
# 2          TLE  Yorkshire and The Humber           1
# 3          TLF   East Midlands (England)           1
# 4          TLG   West Midlands (England)           1
# ...        ...                       ...         ...
# 2034        RO                   România           0
# 2035        NO                     Norge           0
# 2036        PL                    Polska           0
# 2037        PT                  Portugal           0
# 2038        XK                   Kosovo*           0
#
#                                                geometry CNTR_CODE
# 0     MULTIPOLYGON (((-1.22289 54.62587, -1.225 54.6...        UK
# 1     MULTIPOLYGON (((-3.08309 53.25581, -3.0828 53....        UK
# 2     MULTIPOLYGON (((-0.55549 53.69052, -0.54641 53...        UK
# 3     MULTIPOLYGON (((0.26877 52.81586, 0.26747 52.8...        UK
# 4     POLYGON ((-1.3319 52.16849, -1.33309 52.16735,...        UK
# ...                                                 ...       ...
# 2034  MULTIPOLYGON (((26.70918 48.25289, 26.71999 48...        RO
# 2035  MULTIPOLYGON (((27.73163 71.09837, 27.72067 71...        NO
# 2036  MULTIPOLYGON (((18.29486 54.83511, 18.33 54.83...        PL
# 2037  MULTIPOLYGON (((-8.18961 42.13714, -8.19285 42...        PT
# 2038  POLYGON ((20.85278 43.24917, 20.86931 43.23355...        XK
#
# [2039 rows x 5 columns]
