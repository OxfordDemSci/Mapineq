# %% [markdown]
# # international_migration_flow

# %% [markdown]
# This note works to produce the dataset to be put in Mapineq database
# Source: Meta
# Publisher: HDX (https://data.humdata.org/dataset/international-migration-flows)
# New York Times Article: https://www.nytimes.com/interactive/2025/04/17/opinion/global-migration-facebook-data.html
# Special countries: BA, UA, XK, UK/GB, EL/GR

# %%
import os
import gc
import rasterio
import numpy as np
import pandas as pd
from tqdm import tqdm
import geopandas as gpd
from pathlib import Path
import dask_geopandas as dgpd
from osgeo import gdal, osr
from rasterstats import zonal_stats

BASE_DIR = Path('/Users/wenlanzhang/PycharmProjects/Mapineq/src/data-wrangling/')
DATA_DIR = Path('/Users/wenlanzhang/Downloads/PhD_UCL/Data/Oxford')

# %% [markdown]
# # Load NTUS

# %%
# Load a GeoJSON file
gdf_2024 = gpd.read_file(DATA_DIR/"NUTS_RG_01M_2024_3035.geojson")

gdf_country_2024 = gdf_2024[gdf_2024['LEVL_CODE'] == 0]
gdf_country_2024 = gdf_country_2024[['CNTR_CODE', 'geometry']].reset_index(drop=True)
gdf_country_2024
# Out:
#    CNTR_CODE                                           geometry
# 0         EL  MULTIPOLYGON (((6083881.558 1676236.011, 60838...
# 1         ES  MULTIPOLYGON (((3815056.85 1904971.998, 381575...
# 2         FI  MULTIPOLYGON (((4999905.463 5305310.537, 50031...
# 3         FR  MULTIPOLYGON (((9980485.23 -3029930.054, 99812...
# 4         HR  MULTIPOLYGON (((4809521.18 2624665.768, 480963...
# 5         EE  MULTIPOLYGON (((5200614.71 4159725.901, 520083...
# 6         DE  MULTIPOLYGON (((4355225.354 2715902.995, 43548...
# 7         DK  MULTIPOLYGON (((4650283.775 3591676.53, 465057...
# 8         BA  MULTIPOLYGON (((4866544.51 2485914.128, 486624...
# 9         AT  MULTIPOLYGON (((4354847.685 2714710.627, 43552...
# 10        BG  MULTIPOLYGON (((5330611.934 2430822.467, 53320...
# 11        CH  POLYGON ((4214135.431 2744350.058, 4214336.644...
# 12        CY  MULTIPOLYGON (((6526917.298 1761800.522, 65265...
# 13        BE  MULTIPOLYGON (((3961559.829 3161283.432, 39615...
# 14        CZ  MULTIPOLYGON (((4624842.426 3112217.365, 46255...
# 15        AL  MULTIPOLYGON (((5120936.933 2221189.677, 51208...
# 16        LU  POLYGON ((4038553.025 3012676.983, 4039809.513...
# 17        LV  MULTIPOLYGON (((5212108.23 3981598.441, 521208...
# 18        ME  MULTIPOLYGON (((5052329.699 2310654.834, 50526...
# 19        IE  MULTIPOLYGON (((3242847.393 3707490.426, 32428...
# 20        IS  MULTIPOLYGON (((3187388.906 5038641.988, 31881...
# 21        IT  MULTIPOLYGON (((4487109.205 2666691.388, 44901...
# 22        MK  POLYGON ((5332368.904 2222852.634, 5332181.219...
# 23        MT  MULTIPOLYGON (((4716980.384 1445506.163, 47173...
# 24        LI  POLYGON ((4288123.321 2673339.056, 4287968.676...
# 25        NL  MULTIPOLYGON (((4105253.514 3377891.917, 41080...
# 26        LT  MULTIPOLYGON (((5233858.233 3797075.982, 52346...
# 27        HU  POLYGON ((5163698.846 2894269.958, 5165398.316...
# 28        RS  MULTIPOLYGON (((5066429.059 2611967.598, 50671...
# 29        SE  MULTIPOLYGON (((4972068.943 4790066.825, 49723...
# 30        SI  POLYGON ((4796604.927 2660336.458, 4798371.454...
# 31        TR  MULTIPOLYGON (((6352052.667 2451442.258, 63543...
# 32        UA  MULTIPOLYGON (((5869393.902 3502199.025, 58699...
# 33        SK  MULTIPOLYGON (((5003133.924 2988592.038, 50037...
# 34        RO  MULTIPOLYGON (((5550240.663 2933328.113, 55511...
# 35        NO  MULTIPOLYGON (((4962846.066 5411852.375, 49628...
# 36        PL  MULTIPOLYGON (((4852825.195 3556096.333, 48551...
# 37        PT  MULTIPOLYGON (((2828494.611 2296190.204, 28279...
# 38        XK  POLYGON ((5201301.166 2301673.012, 5202865.563...

# %%
# Load a GeoJSON file
gdf_2021 = gpd.read_file(DATA_DIR/"NUTS_RG_01M_2021_3035.geojson")

gdf_country_2021 = gdf_2021[gdf_2021['LEVL_CODE'] == 0]
gdf_country_2021 = gdf_country_2021[['CNTR_CODE', 'geometry']].reset_index(drop=True)
uk_2021 = gdf_country_2021[gdf_country_2021['CNTR_CODE'] == 'UK']
uk_2021
# Out:
#    CNTR_CODE                                           geometry
# 34        UK  MULTIPOLYGON (((3546135.14 4022028.934, 354660...

# %%
# Concatenate with 2024 data
gdf_country = pd.concat(
    [gdf_country_2024, uk_2021],
    ignore_index=True  # Reset index
)
gdf_country
# Out:
#    CNTR_CODE                                           geometry
# 0         EL  MULTIPOLYGON (((6083881.558 1676236.011, 60838...
# 1         ES  MULTIPOLYGON (((3815056.85 1904971.998, 381575...
# 2         FI  MULTIPOLYGON (((4999905.463 5305310.537, 50031...
# 3         FR  MULTIPOLYGON (((9980485.23 -3029930.054, 99812...
# 4         HR  MULTIPOLYGON (((4809521.18 2624665.768, 480963...
# 5         EE  MULTIPOLYGON (((5200614.71 4159725.901, 520083...
# 6         DE  MULTIPOLYGON (((4355225.354 2715902.995, 43548...
# 7         DK  MULTIPOLYGON (((4650283.775 3591676.53, 465057...
# 8         BA  MULTIPOLYGON (((4866544.51 2485914.128, 486624...
# 9         AT  MULTIPOLYGON (((4354847.685 2714710.627, 43552...
# 10        BG  MULTIPOLYGON (((5330611.934 2430822.467, 53320...
# 11        CH  POLYGON ((4214135.431 2744350.058, 4214336.644...
# 12        CY  MULTIPOLYGON (((6526917.298 1761800.522, 65265...
# 13        BE  MULTIPOLYGON (((3961559.829 3161283.432, 39615...
# 14        CZ  MULTIPOLYGON (((4624842.426 3112217.365, 46255...
# 15        AL  MULTIPOLYGON (((5120936.933 2221189.677, 51208...
# 16        LU  POLYGON ((4038553.025 3012676.983, 4039809.513...
# 17        LV  MULTIPOLYGON (((5212108.23 3981598.441, 521208...
# 18        ME  MULTIPOLYGON (((5052329.699 2310654.834, 50526...
# 19        IE  MULTIPOLYGON (((3242847.393 3707490.426, 32428...
# 20        IS  MULTIPOLYGON (((3187388.906 5038641.988, 31881...
# 21        IT  MULTIPOLYGON (((4487109.205 2666691.388, 44901...
# 22        MK  POLYGON ((5332368.904 2222852.634, 5332181.219...
# 23        MT  MULTIPOLYGON (((4716980.384 1445506.163, 47173...
# 24        LI  POLYGON ((4288123.321 2673339.056, 4287968.676...
# 25        NL  MULTIPOLYGON (((4105253.514 3377891.917, 41080...
# 26        LT  MULTIPOLYGON (((5233858.233 3797075.982, 52346...
# 27        HU  POLYGON ((5163698.846 2894269.958, 5165398.316...
# 28        RS  MULTIPOLYGON (((5066429.059 2611967.598, 50671...
# 29        SE  MULTIPOLYGON (((4972068.943 4790066.825, 49723...
# 30        SI  POLYGON ((4796604.927 2660336.458, 4798371.454...
# 31        TR  MULTIPOLYGON (((6352052.667 2451442.258, 63543...
# 32        UA  MULTIPOLYGON (((5869393.902 3502199.025, 58699...
# 33        SK  MULTIPOLYGON (((5003133.924 2988592.038, 50037...
# 34        RO  MULTIPOLYGON (((5550240.663 2933328.113, 55511...
# 35        NO  MULTIPOLYGON (((4962846.066 5411852.375, 49628...
# 36        PL  MULTIPOLYGON (((4852825.195 3556096.333, 48551...
# 37        PT  MULTIPOLYGON (((2828494.611 2296190.204, 28279...
# 38        XK  POLYGON ((5201301.166 2301673.012, 5202865.563...
# 39        UK  MULTIPOLYGON (((3546135.14 4022028.934, 354660...

# %%
country_list = gdf_country['CNTR_CODE'].unique()
len(country_list)
country_list
# Out:
# array(['EL', 'ES', 'FI', 'FR', 'HR', 'EE', 'DE', 'DK', 'BA', 'AT', 'BG',
#        'CH', 'CY', 'BE', 'CZ', 'AL', 'LU', 'LV', 'ME', 'IE', 'IS', 'IT',
#        'MK', 'MT', 'LI', 'NL', 'LT', 'HU', 'RS', 'SE', 'SI', 'TR', 'UA',
#        'SK', 'RO', 'NO', 'PL', 'PT', 'XK', 'UK'], dtype=object)

# %% [markdown]
# # Load Migration

# %%
df = pd.read_csv(DATA_DIR/f"Migration/international_migration_flow.csv") 
df['year'] = pd.to_datetime(df['migration_month']).dt.year
df['month'] = pd.to_datetime(df['migration_month']).dt.month

# Define the mapping of old codes to new codes
country_code_mapping = {
    'GR': 'EL',  # Greece (GR → EL)
    'GB': 'UK'   # United Kingdom (GB → UK)
}

# Apply the replacement to both columns
df['country_from'] = df['country_from'].replace(country_code_mapping)
df['country_to'] = df['country_to'].replace(country_code_mapping)

df
# len(df['country_from'].unique())
# Out:
#         country_from country_to migration_month  num_migrants  year  month
# 0                 AD         AE         2019-01            12  2019      1
# 1                 AD         AE         2019-02             2  2019      2
# 2                 AD         AE         2019-03             1  2019      3
# 3                 AD         AE         2019-04             7  2019      4
# 4                 AD         AE         2019-05             0  2019      5
# ...              ...        ...             ...           ...   ...    ...
# 1563149           ZW         ZM         2022-08           138  2022      8
# 1563150           ZW         ZM         2022-09           162  2022      9
# 1563151           ZW         ZM         2022-10           149  2022     10
# 1563152           ZW         ZM         2022-11           104  2022     11
# 1563153           ZW         ZM         2022-12            99  2022     12
#
# [1563154 rows x 6 columns]

# %%
len(df['country_to'].unique())
# df['country_to'].unique()

# df[df['country_to'].isna()].groupby('country_from').size().unique()
# df[df['country_from'].isna()].groupby('country_to').size().unique()
# Out:
# 181

# %% [markdown]
# # Country Aggregation

# %%
def prepare_flow_data(df_input, flow_type: str, country_scope: str, country_list: list):
    # Determine the column based on flow direction
    flow_col = 'country_to' if flow_type == 'inflow' else 'country_from'

    # Optional: filter for EU countries
    if country_scope == 'eu_countries':
        df_input = df_input[df_input[flow_col].isin(country_list)]

    # Ensure 'month' column exists
    if 'month' not in df_input.columns:
        df_input['month'] = pd.to_datetime(df_input['migration_month']).dt.month

    # Yearly aggregation
    yearly = (
        df_input.groupby([flow_col, 'year'])
        .agg(migration_count_total=('num_migrants', 'sum'))
        .reset_index()
        .assign(month='all')  # Placeholder month
        .rename(columns={flow_col: 'geo', 'year': 'obsTime'})
    )

    # Monthly aggregation
    monthly = (
        df_input.groupby([flow_col, 'year', 'month'])
        .agg(migration_count_total=('num_migrants', 'sum'))
        .reset_index()
        .rename(columns={flow_col: 'geo', 'year': 'obsTime'})
    )

    # Combine both
    combined = pd.concat([yearly, monthly], ignore_index=True)

    # Melt to long format
    melted = combined.melt(
        id_vars=['geo', 'obsTime', 'month'],
        value_vars=['migration_count_total'],
        var_name='time_granularity',
        value_name='obsValue'
    )

    # Clean and tag
    melted['time_granularity'] = melted['time_granularity'].map({
        'migration_count_total': 'Total Migration'
    })
    melted['flow_type'] = flow_type
    melted['country'] = country_scope

    return melted

# %%
# Inflow
inflow_all = prepare_flow_data(df, 'inflow', 'all_countries', country_list)
# inflow_eu = prepare_flow_data(df, 'inflow', 'eu_countries', country_list)
# inflow_combined = pd.concat([inflow_all, inflow_eu], ignore_index=True)

# Outflow
outflow_all = prepare_flow_data(df, 'outflow', 'all_countries', country_list)
# outflow_eu = prepare_flow_data(df, 'outflow', 'eu_countries', country_list)
# outflow_combined = pd.concat([outflow_all, outflow_eu], ignore_index=True)

# Combine inflow and outflow into one final dataset
# migration_combined = pd.concat([inflow_combined, outflow_combined], ignore_index=True)
migration_combined = pd.concat([inflow_all, outflow_all], ignore_index=True)
migration_combined
# Out:
#       geo  obsTime month time_granularity  obsValue flow_type        country
# 0      AD     2019   all  Total Migration      8390    inflow  all_countries
# 1      AD     2020   all  Total Migration      7908    inflow  all_countries
# 2      AD     2021   all  Total Migration      6923    inflow  all_countries
# 3      AD     2022   all  Total Migration      9685    inflow  all_countries
# 4      AE     2019   all  Total Migration   1248145    inflow  all_countries
# ...    ..      ...   ...              ...       ...       ...            ...
# 18715  ZW     2022     8  Total Migration      4339   outflow  all_countries
# 18716  ZW     2022     9  Total Migration      4867   outflow  all_countries
# 18717  ZW     2022    10  Total Migration      6280   outflow  all_countries
# 18718  ZW     2022    11  Total Migration      5907   outflow  all_countries
# 18719  ZW     2022    12  Total Migration      7277   outflow  all_countries
#
# [18720 rows x 7 columns]

# %%
migration_combined['geo'].unique()
# Out:
# array(['AD', 'AE', 'AF', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA',
#        'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR',
#        'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CF', 'CG', 'CH', 'CI',
#        'CL', 'CM', 'CO', 'CR', 'CV', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DO',
#        'DZ', 'EC', 'EE', 'EG', 'EL', 'ER', 'ES', 'ET', 'FI', 'FJ', 'FM',
#        'FR', 'GA', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GT', 'GW', 'GY',
#        'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS',
#        'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KR', 'KW',
#        'KZ', 'LA', 'LB', 'LC', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY',
#        'MA', 'MD', 'ME', 'MG', 'MK', 'ML', 'MM', 'MN', 'MO', 'MR', 'MT',
#        'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NE', 'NG', 'NI', 'NL', 'NO',
#        'NP', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PT', 'PY',
#        'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SD', 'SE', 'SG', 'SI',
#        'SK', 'SL', 'SN', 'SR', 'SS', 'ST', 'SV', 'SY', 'SZ', 'TD', 'TG',
#        'TH', 'TJ', 'TL', 'TM', 'TN', 'TO', 'TR', 'TT', 'TW', 'TZ', 'UA',
#        'UG', 'UK', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK',
#        'YE', 'ZA', 'ZM', 'ZW'], dtype=object)

# %% [markdown]
# # Individual Country

# %%
# Create inflow DataFrame
inflow_df = df.rename(columns={
    'country_to': 'geo',
    'country_from': 'country'
})
inflow_df['flow_type'] = 'inflow'

# Create outflow DataFrame
outflow_df = df.rename(columns={
    'country_from': 'geo',
    'country_to': 'country',
})
outflow_df['flow_type'] = 'outflow'

# Concatenate both
individual_df = pd.concat([inflow_df, outflow_df], ignore_index=True)

# Optional: reorder columns
individual_df = individual_df.rename(columns={
    'num_migrants': 'obsValue',
    'year': 'obsTime',
})
individual_df['time_granularity'] = 'Monthly'
individual_df = individual_df[['geo', 'obsTime', 'month', 'time_granularity', 'obsValue', 'flow_type', 'country']]
individual_df
# Out:
#         geo  obsTime  month time_granularity  obsValue flow_type country
# 0        AE     2019      1          Monthly        12    inflow      AD
# 1        AE     2019      2          Monthly         2    inflow      AD
# 2        AE     2019      3          Monthly         1    inflow      AD
# 3        AE     2019      4          Monthly         7    inflow      AD
# 4        AE     2019      5          Monthly         0    inflow      AD
# ...      ..      ...    ...              ...       ...       ...     ...
# 3126303  ZW     2022      8          Monthly       138   outflow      ZM
# 3126304  ZW     2022      9          Monthly       162   outflow      ZM
# 3126305  ZW     2022     10          Monthly       149   outflow      ZM
# 3126306  ZW     2022     11          Monthly       104   outflow      ZM
# 3126307  ZW     2022     12          Monthly        99   outflow      ZM
#
# [3126308 rows x 7 columns]

# %% [markdown]
# # Check
# Same country, Same year, Same flow direction should have same number

# %%
# individual_df[(individual_df['geo'] == 'AE') & (individual_df['obsTime'] == 2019) & (individual_df['flow_type'] == 'inflow') & (individual_df['month'] == 1)]['obsValue'].sum()
individual_df[(individual_df['geo'] == 'AE') & (individual_df['obsTime'] == 2019) & (individual_df['flow_type'] == 'inflow')]['obsValue'].sum()
# Out:
# np.int64(1248145)

# %%
migration_combined[(migration_combined['geo'] == 'AE') & (migration_combined['obsTime'] == 2019) & (migration_combined['flow_type'] == 'inflow') & (migration_combined['month'] == 'all')]
# Out:
#   geo  obsTime month time_granularity  obsValue flow_type        country
# 4  AE     2019   all  Total Migration   1248145    inflow  all_countries

# %%
migration_combined[(migration_combined['geo'] == 'AE') & (migration_combined['obsTime'] == 2019) & (migration_combined['flow_type'] == 'inflow') & (migration_combined['month'] != 'all')]['obsValue'].sum()
# Out:
# np.int64(1248145)

# %% [markdown]
# # Final Combine

# %%
final = pd.concat([individual_df, migration_combined], ignore_index=True)
final
# Out:
#         geo  obsTime month time_granularity  obsValue flow_type        country
# 0        AE     2019     1          Monthly        12    inflow             AD
# 1        AE     2019     2          Monthly         2    inflow             AD
# 2        AE     2019     3          Monthly         1    inflow             AD
# 3        AE     2019     4          Monthly         7    inflow             AD
# 4        AE     2019     5          Monthly         0    inflow             AD
# ...      ..      ...   ...              ...       ...       ...            ...
# 3145023  ZW     2022     8  Total Migration      4339   outflow  all_countries
# 3145024  ZW     2022     9  Total Migration      4867   outflow  all_countries
# 3145025  ZW     2022    10  Total Migration      6280   outflow  all_countries
# 3145026  ZW     2022    11  Total Migration      5907   outflow  all_countries
# 3145027  ZW     2022    12  Total Migration      7277   outflow  all_countries
#
# [3145028 rows x 7 columns]

# %% [markdown]
# # Merge

# %%
merged_migration = final.merge(gdf_country, left_on='geo', right_on='CNTR_CODE', how='inner').drop(columns='CNTR_CODE')

merged_migration['geo_source'] = np.where(
    merged_migration['geo'] == 'UK',  # Condition
    'NUTS2021',                             # Value if True (UK)
    'NUTS2024'                              # Value if False (all others)
)

merged_migration
# Out:
#        geo  obsTime month time_granularity  obsValue flow_type        country  \
# 0       AL     2019     1          Monthly         0    inflow             AD
# 1       AL     2019     2          Monthly         5    inflow             AD
# 2       AL     2019     3          Monthly         2    inflow             AD
# 3       AL     2019     4          Monthly         0    inflow             AD
# 4       AL     2019     5          Monthly         0    inflow             AD
# ...     ..      ...   ...              ...       ...       ...            ...
# 677297  XK     2022     8  Total Migration      2690   outflow  all_countries
# 677298  XK     2022     9  Total Migration      4658   outflow  all_countries
# 677299  XK     2022    10  Total Migration      6711   outflow  all_countries
# 677300  XK     2022    11  Total Migration      3905   outflow  all_countries
# 677301  XK     2022    12  Total Migration      3887   outflow  all_countries
#
#                                                  geometry geo_source
# 0       MULTIPOLYGON (((5120936.933 2221189.677, 51208...   NUTS2024
# 1       MULTIPOLYGON (((5120936.933 2221189.677, 51208...   NUTS2024
# 2       MULTIPOLYGON (((5120936.933 2221189.677, 51208...   NUTS2024
# 3       MULTIPOLYGON (((5120936.933 2221189.677, 51208...   NUTS2024
# 4       MULTIPOLYGON (((5120936.933 2221189.677, 51208...   NUTS2024
# ...                                                   ...        ...
# 677297  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 677298  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 677299  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 677300  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 677301  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
#
# [677302 rows x 9 columns]

# %%
len(merged_migration['geo'].unique())
# Out:
# 39

# %%
merged_migration[merged_migration['geo'] == 'XK']
# Out:
#        geo  obsTime month time_granularity  obsValue flow_type        country  \
# 1824    XK     2019     1          Monthly         0    inflow             AD
# 1825    XK     2019     2          Monthly         0    inflow             AD
# 1826    XK     2019     3          Monthly         0    inflow             AD
# 1827    XK     2019     4          Monthly         9    inflow             AD
# 1828    XK     2019     5          Monthly         2    inflow             AD
# ...     ..      ...   ...              ...       ...       ...            ...
# 677297  XK     2022     8  Total Migration      2690   outflow  all_countries
# 677298  XK     2022     9  Total Migration      4658   outflow  all_countries
# 677299  XK     2022    10  Total Migration      6711   outflow  all_countries
# 677300  XK     2022    11  Total Migration      3905   outflow  all_countries
# 677301  XK     2022    12  Total Migration      3887   outflow  all_countries
#
#                                                  geometry geo_source
# 1824    POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 1825    POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 1826    POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 1827    POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 1828    POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# ...                                                   ...        ...
# 677297  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 677298  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 677299  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 677300  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 677301  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
#
# [17288 rows x 9 columns]

# %% [markdown]
# # Export

# %%
# # Ensure merged is a GeoDataFrame
gdf_merged = gpd.GeoDataFrame(merged_migration, geometry='geometry')

# %%
# # Export without the geometry column
merged_migration.drop(columns='geometry').to_csv(DATA_DIR/"Migration/Output/international_migration.csv", index=True, index_label="id")

# %%
# Export with the geometry column
gdf_merged_country = gdf_merged[(gdf_merged['country'] == 'all_countries') & (gdf_merged['month'] != 'all')]
gdf_merged_country.to_csv(DATA_DIR/"Migration/Processed/international_migration_all_country_bymonth.csv", index=True, index_label="id")

# %%
gdf_merged_country
# Out:
#        geo  obsTime month time_granularity  obsValue flow_type        country  \
# 673246  AL     2019   all  Total Migration     33450    inflow  all_countries
# 673247  AL     2020   all  Total Migration     34778    inflow  all_countries
# 673248  AL     2021   all  Total Migration     30131    inflow  all_countries
# 673249  AL     2022   all  Total Migration     28662    inflow  all_countries
# 673250  AT     2019   all  Total Migration    103587    inflow  all_countries
# ...     ..      ...   ...              ...       ...       ...            ...
# 675425  UK     2022   all  Total Migration    442728   outflow  all_countries
# 675426  XK     2019   all  Total Migration     35189   outflow  all_countries
# 675427  XK     2020   all  Total Migration     31446   outflow  all_countries
# 675428  XK     2021   all  Total Migration     34511   outflow  all_countries
# 675429  XK     2022   all  Total Migration     49903   outflow  all_countries
#
#                                                  geometry geo_source
# 673246  MULTIPOLYGON (((5120936.933 2221189.677, 51208...   NUTS2024
# 673247  MULTIPOLYGON (((5120936.933 2221189.677, 51208...   NUTS2024
# 673248  MULTIPOLYGON (((5120936.933 2221189.677, 51208...   NUTS2024
# 673249  MULTIPOLYGON (((5120936.933 2221189.677, 51208...   NUTS2024
# 673250  MULTIPOLYGON (((4354847.685 2714710.627, 43552...   NUTS2024
# ...                                                   ...        ...
# 675425  MULTIPOLYGON (((3546135.14 4022028.934, 354660...   NUTS2021
# 675426  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 675427  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 675428  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
# 675429  POLYGON ((5201301.166 2301673.012, 5202865.563...   NUTS2024
#
# [312 rows x 9 columns]

# %%
# Reproject only once
gdf_country_ll = gdf_country.to_crs("EPSG:3857")

# Compute centroid and extract coordinates
gdf_country_ll['centroid'] = gdf_country_ll.geometry.centroid
gdf_country_ll['lon'] = gdf_country_ll['centroid'].x
gdf_country_ll['lat'] = gdf_country_ll['centroid'].y

country_coords = gdf_country_ll[['CNTR_CODE', 'lon', 'lat']].copy()
country_coords

gdf_country_ll
# Out:
#    CNTR_CODE                                           geometry  \
# 0         EL  MULTIPOLYGON (((3298938.638 4315586.622, 32988...
# 1         ES  MULTIPOLYGON (((455733.008 4874933.93, 456795....
# 2         FI  MULTIPOLYGON (((3101760.532 11095778.494, 3112...
# 3         FR  MULTIPOLYGON (((6172016.137 -2376935.15, 61727...
# 4         HR  MULTIPOLYGON (((1822508.409 5868370.87, 182262...
# 5         EE  MULTIPOLYGON (((2862671.48 8323714.126, 286289...
# 6         DE  MULTIPOLYGON (((1163782.809 6033270.891, 11632...
# 7         DK  MULTIPOLYGON (((1690946.745 7424862.027, 16914...
# 8         BA  MULTIPOLYGON (((1886912.567 5661971.675, 18864...
# 9         AT  MULTIPOLYGON (((1163214.211 6031504.349, 11637...
# 10        BG  MULTIPOLYGON (((2524187.411 5498877.397, 25260...
# 11        CH  POLYGON ((954468.539 6074224.235, 954777.785 6...
# 12        CY  MULTIPOLYGON (((3851994.482 4259853.271, 38514...
# 13        BE  MULTIPOLYGON (((537083.125 6700855.325, 537342...
# 14        CZ  MULTIPOLYGON (((1595762.385 6628397.549, 15968...
# 15        AL  MULTIPOLYGON (((2198773.331 5255738.944, 21985...
# 16        LU  POLYGON ((673003.492 6473649.854, 674999.289 6...
# 17        LV  MULTIPOLYGON (((2806758.142 7983408.367, 28063...
# 18        ME  MULTIPOLYGON (((2120091.219 5389495.329, 21205...
# 19        IE  MULTIPOLYGON (((-796905.228 7422004.771, -7962...
# 20        IS  MULTIPOLYGON (((-1780505.638 10019915.634, -17...
# 21        IT  MULTIPOLYGON (((1356577.726 5957058.538, 13609...
# 22        MK  POLYGON ((2482241.733 5215874.564, 2481824.241...
# 23        MT  MULTIPOLYGON (((1597562.915 4296417.52, 159799...
# 24        LI  POLYGON ((1064957.166 5970317.413, 1064732.53 ...
# 25        NL  MULTIPOLYGON (((751467.306 7069540.872, 756162...
# 26        LT  MULTIPOLYGON (((2772308.415 7642408.459, 27732...
# 27        HU  POLYGON ((2389748.943 6202266.212, 2392046.261...
# 28        RS  MULTIPOLYGON (((2190183.289 5809791.807, 21911...
# 29        SE  MULTIPOLYGON (((2687550.628 9774210.609, 26880...
# 30        SI  POLYGON ((1808024.327 5921904.111, 1810555.374...
# 31        TR  MULTIPOLYGON (((3894097.871 5174929.113, 38972...
# 32        UA  MULTIPOLYGON (((3694878.148 6868899.759, 36956...
# 33        SK  MULTIPOLYGON (((2167099.534 6379653.815, 21678...
# 34        RO  MULTIPOLYGON (((2973252.642 6149030.746, 29744...
# 35        NO  MULTIPOLYGON (((3087070.459 11435990.954, 3085...
# 36        PL  MULTIPOLYGON (((2036575.055 7329929.353, 20404...
# 37        PT  MULTIPOLYGON (((-911663.124 5181544.303, -9120...
# 38        XK  POLYGON ((2321321.286 5349975.354, 2323160.849...
# 39        UK  MULTIPOLYGON (((-379758.207 8103023.892, -3794...
#
#                             centroid           lon           lat
# 0     POINT (2557818.465 4735784.59)  2.557818e+06  4.735785e+06
# 1    POINT (-403205.361 4915380.798) -4.032054e+05  4.915381e+06
# 2    POINT (2923520.484 9578864.637)  2.923520e+06  9.578865e+06
# 3    POINT (-138045.184 5490616.641) -1.380452e+05  5.490617e+06
# 4    POINT (1826178.186 5630635.442)  1.826178e+06  5.630635e+06
# 5    POINT (2843518.811 8111840.027)  2.843519e+06  8.111840e+06
# 6    POINT (1157958.025 6660331.023)  1.157958e+06  6.660331e+06
# 7    POINT (1118425.905 7554263.825)  1.118426e+06  7.554264e+06
# 8    POINT (1979510.332 5492972.626)  1.979510e+06  5.492973e+06
# 9    POINT (1575016.481 6040108.883)  1.575016e+06  6.040109e+06
# 10   POINT (2809579.617 5276946.739)  2.809580e+06  5.276947e+06
# 11    POINT (916223.785 5910362.208)  9.162238e+05  5.910362e+06
# 12   POINT (3698784.183 4170805.828)  3.698784e+06  4.170806e+06
# 13     POINT (518461.15 6559098.808)  5.184612e+05  6.559099e+06
# 14   POINT (1706286.953 6402751.096)  1.706287e+06  6.402751e+06
# 15   POINT (2233390.673 5034732.478)  2.233391e+06  5.034732e+06
# 16    POINT (678182.612 6407869.474)  6.781826e+05  6.407869e+06
# 17   POINT (2774456.066 7732321.079)  2.774456e+06  7.732321e+06
# 18   POINT (2143154.137 5280010.468)  2.143154e+06  5.280010e+06
# 19   POINT (-906762.789 7020976.258) -9.067628e+05  7.020976e+06
# 20  POINT (-2068060.755 9611669.327) -2.068061e+06  9.611669e+06
# 21   POINT (1337112.188 5305241.026)  1.337112e+06  5.305241e+06
# 22   POINT (2415819.044 5101750.527)  2.415819e+06  5.101751e+06
# 23   POINT (1602999.628 4289954.865)  1.603000e+06  4.289955e+06
# 24    POINT (1063428.338 5965251.34)  1.063428e+06  5.965251e+06
# 25    POINT (622535.945 6851144.181)  6.225359e+05  6.851144e+06
# 26   POINT (2660010.862 7430284.616)  2.660011e+06  7.430285e+06
# 27      POINT (2161881.85 5971030.3)  2.161882e+06  5.971030e+06
# 28   POINT (2313834.947 5504591.656)  2.313835e+06  5.504592e+06
# 29   POINT (1893062.046 9199906.578)  1.893062e+06  9.199907e+06
# 30   POINT (1650156.787 5800001.481)  1.650157e+06  5.800001e+06
# 31   POINT (3914419.761 4736511.622)  3.914420e+06  4.736512e+06
# 32    POINT (3490131.457 6291142.83)  3.490131e+06  6.291143e+06
# 33   POINT (2169621.278 6226211.294)  2.169621e+06  6.226211e+06
# 34    POINT (2780697.473 5760107.26)  2.780697e+06  5.760107e+06
# 35  POINT (1867548.553 12210167.773)  1.867549e+06  1.221017e+07
# 36   POINT (2158079.947 6834014.183)  2.158080e+06  6.834014e+06
# 37   POINT (-945894.559 4814412.677) -9.458946e+05  4.814413e+06
# 38    POINT (2325391.07 5248770.516)  2.325391e+06  5.248771e+06
# 39    POINT (-328655.546 7238218.55) -3.286555e+05  7.238219e+06

# %%
# Merge origin country (FROM)
df_from = df.merge(country_coords, left_on='country_from', right_on='CNTR_CODE', how='left')
df_from.rename(columns={'lon': 'start_lon', 'lat': 'start_lat'}, inplace=True)
df_from.drop(columns='CNTR_CODE', inplace=True)  # Drop to avoid conflict in next merge
df_from
# Out:
#         country_from country_to migration_month  num_migrants  year  month  \
# 0                 AD         AE         2019-01            12  2019      1
# 1                 AD         AE         2019-02             2  2019      2
# 2                 AD         AE         2019-03             1  2019      3
# 3                 AD         AE         2019-04             7  2019      4
# 4                 AD         AE         2019-05             0  2019      5
# ...              ...        ...             ...           ...   ...    ...
# 1563149           ZW         ZM         2022-08           138  2022      8
# 1563150           ZW         ZM         2022-09           162  2022      9
# 1563151           ZW         ZM         2022-10           149  2022     10
# 1563152           ZW         ZM         2022-11           104  2022     11
# 1563153           ZW         ZM         2022-12            99  2022     12
#
#          start_lon  start_lat
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN
# ...            ...        ...
# 1563149        NaN        NaN
# 1563150        NaN        NaN
# 1563151        NaN        NaN
# 1563152        NaN        NaN
# 1563153        NaN        NaN
#
# [1563154 rows x 8 columns]

# %%
# Merge destination country (TO)
df_to = df_from.merge(country_coords, left_on='country_to', right_on='CNTR_CODE', how='left')
df_to.rename(columns={'lon': 'end_lon', 'lat': 'end_lat'}, inplace=True)
df_to.drop(columns='CNTR_CODE', inplace=True)
df_to
# Out:
#         country_from country_to migration_month  num_migrants  year  month  \
# 0                 AD         AE         2019-01            12  2019      1
# 1                 AD         AE         2019-02             2  2019      2
# 2                 AD         AE         2019-03             1  2019      3
# 3                 AD         AE         2019-04             7  2019      4
# 4                 AD         AE         2019-05             0  2019      5
# ...              ...        ...             ...           ...   ...    ...
# 1563149           ZW         ZM         2022-08           138  2022      8
# 1563150           ZW         ZM         2022-09           162  2022      9
# 1563151           ZW         ZM         2022-10           149  2022     10
# 1563152           ZW         ZM         2022-11           104  2022     11
# 1563153           ZW         ZM         2022-12            99  2022     12
#
#          start_lon  start_lat  end_lon  end_lat
# 0              NaN        NaN      NaN      NaN
# 1              NaN        NaN      NaN      NaN
# 2              NaN        NaN      NaN      NaN
# 3              NaN        NaN      NaN      NaN
# 4              NaN        NaN      NaN      NaN
# ...            ...        ...      ...      ...
# 1563149        NaN        NaN      NaN      NaN
# 1563150        NaN        NaN      NaN      NaN
# 1563151        NaN        NaN      NaN      NaN
# 1563152        NaN        NaN      NaN      NaN
# 1563153        NaN        NaN      NaN      NaN
#
# [1563154 rows x 10 columns]

# %%
clean_df = df_to.dropna(subset=['start_lon', 'start_lat', 'end_lon', 'end_lat'])
clean_df
# Out:
#         country_from country_to migration_month  num_migrants  year  month  \
# 26206             AL         AT         2019-01            34  2019      1
# 26207             AL         AT         2019-02            23  2019      2
# 26208             AL         AT         2019-03            36  2019      3
# 26209             AL         AT         2019-04            46  2019      4
# 26210             AL         AT         2019-05            26  2019      5
# ...              ...        ...             ...           ...   ...    ...
# 1527965           XK         UA         2022-08             8  2022      8
# 1527966           XK         UA         2022-09            12  2022      9
# 1527967           XK         UA         2022-10             2  2022     10
# 1527968           XK         UA         2022-11             6  2022     11
# 1527969           XK         UA         2022-12             6  2022     12
#
#             start_lon     start_lat       end_lon       end_lat
# 26206    2.233391e+06  5.034732e+06  1.575016e+06  6.040109e+06
# 26207    2.233391e+06  5.034732e+06  1.575016e+06  6.040109e+06
# 26208    2.233391e+06  5.034732e+06  1.575016e+06  6.040109e+06
# 26209    2.233391e+06  5.034732e+06  1.575016e+06  6.040109e+06
# 26210    2.233391e+06  5.034732e+06  1.575016e+06  6.040109e+06
# ...               ...           ...           ...           ...
# 1527965  2.325391e+06  5.248771e+06  3.490131e+06  6.291143e+06
# 1527966  2.325391e+06  5.248771e+06  3.490131e+06  6.291143e+06
# 1527967  2.325391e+06  5.248771e+06  3.490131e+06  6.291143e+06
# 1527968  2.325391e+06  5.248771e+06  3.490131e+06  6.291143e+06
# 1527969  2.325391e+06  5.248771e+06  3.490131e+06  6.291143e+06
#
# [70848 rows x 10 columns]

# %%
clean_df.to_csv(DATA_DIR/"Migration/Processed/Individual_Flow_3857.csv", index=True)
