# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\AX\Desktop\gadm1_nuts2-gadm1_nuts2-fb-social-connectedness-index-october-2021.tsv', sep='\t')

# %%
df.head(50)
# Out:
#    user_loc fr_loc  scaled_sci
# 0       ABW    ABW    28858054
# 1       ABW   AGO1          96
# 2       ABW  AGO10          86
# 3       ABW  AGO11          81
# 4       ABW  AGO12          56
# 5       ABW  AGO13          94
# 6       ABW  AGO14          76
# 7       ABW  AGO15          65
# 8       ABW  AGO16         111
# 9       ABW  AGO17          73
# 10      ABW  AGO18          82
# 11      ABW   AGO2          93
# 12      ABW   AGO3         107
# 13      ABW   AGO4          73
# 14      ABW   AGO5         102
# 15      ABW   AGO6          84
# 16      ABW   AGO7          92
# 17      ABW   AGO8         112
# 18      ABW   AGO9          85
# 19      ABW   AL01          38
# 20      ABW   AL02          97
# 21      ABW   AL03          33
# 22      ABW    AND         609
# 23      ABW   ARE1         212
# 24      ABW   ARE2          86
# 25      ABW   ARE3         341
# 26      ABW   ARE4         104
# 27      ABW   ARE5          15
# 28      ABW   ARE6         103
# ...
